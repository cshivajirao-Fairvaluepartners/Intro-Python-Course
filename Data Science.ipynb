# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv("https://raw.githubusercontent.com/tidyverse/ggplot2/master/data-raw/diamonds.csv")

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.head(7)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47

# %%
type(diamonds)
# Out:
# pandas.core.frame.DataFrame

# %%
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
diamonds.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
diamonds["carat"]
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
diamonds.carat
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds['price_gbp'] = diamonds['price']*0.74

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_gbp
# 0     241.24
# 1     241.24
# 2     241.98
# 3     247.16
# 4     247.90

# %%
diamonds['price'].mean()
# Out:
# 3932.799721913237

# %%
diamonds['price'].median()
# Out:
# 2401.0

# %%
np.mean(diamonds['price'])
# Out:
# 3932.799721913237

# %%
diamonds['price'].std()
# Out:
# 3989.4397381463023

# %%
diamonds['price'].quantile(0.333)
# Out:
# 1239.0

# %%
diamonds.mean()
# Out:
# carat           0.797940
# depth          61.749405
# table          57.457184
# price        3932.799722
# x               5.731157
# y               5.734526
# z               3.538734
# price_gbp    2910.271794
# dtype: float64

# %%
diamonds['price'].describe()
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64

# %%
diamonds['price']
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z     price_gbp
# count  53940.000000  53940.000000  53940.000000
# mean       5.734526      3.538734   2910.271794
# std        1.142135      0.705699   2952.185406
# min        0.000000      0.000000    241.240000
# ...

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_gbp
# 0     241.24
# 1     241.24
# 2     241.98
# 3     247.16
# 4     247.90

# %%
diamonds['cut'].describe()
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object

# %%
diamonds["cut"].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
pd.crosstab(diamonds['cut'], diamonds['color'])
# Out:
# color         D     E     F     G     H     I    J
# cut
# Fair        163   224   312   314   303   175  119
# Good        662   933   909   871   702   522  307
# Ideal      2834  3903  3826  4884  3115  2093  896
# Premium    1603  2337  2331  2924  2360  1428  808
# Very Good  1513  2400  2164  2299  1824  1204  678

# %% [markdown]
# # Filtering

# %%
ex = diamonds['cut'].head()

# %%
ex
# Out:
# 0      Ideal
# 1    Premium
# 2       Good
# 3    Premium
# 4       Good
# Name: cut, dtype: object

# %%
ex == 'Premium'
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: cut, dtype: bool

# %%
ex[ex == 'Premium']
# Out:
# 1    Premium
# 3    Premium
# Name: cut, dtype: object

# %%
ex[ex != 'Premium']
# Out:
# 0    Ideal
# 2     Good
# 4     Good
# Name: cut, dtype: object

# %%
diamonds[diamonds['cut'] == 'Ideal']
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z  \
# 0       0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 11      0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13      0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16      0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 39      0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53925   0.79  Ideal     I     SI1   61.6   56.0   2756  5.95  5.97  3.67
# 53926   0.71  Ideal     E     SI1   61.9   56.0   2756  5.71  5.73  3.54
# 53929   0.71  Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
# 53935   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53939   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        price_gbp
# 0         241.24
# 11        251.60
# 13        254.56
# 16        257.52
# ...

# %%
is_ideal_cut = diamonds['cut'] == 'Ideal'
diamonds[is_ideal_cut]
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z  \
# 0       0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 11      0.23  Ideal     J     VS1   62.8   56.0    340  3.93  3.90  2.46
# 13      0.31  Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16      0.30  Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# 39      0.33  Ideal     I     SI2   61.8   55.0    403  4.49  4.51  2.78
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53925   0.79  Ideal     I     SI1   61.6   56.0   2756  5.95  5.97  3.67
# 53926   0.71  Ideal     E     SI1   61.9   56.0   2756  5.71  5.73  3.54
# 53929   0.71  Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
# 53935   0.72  Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53939   0.75  Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        price_gbp
# 0         241.24
# 11        251.60
# 13        254.56
# 16        257.52
# ...

# %%
is_ideal_cut
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935     True
# 53936    False
# 53937    False
# 53938    False
# 53939     True
# Name: cut, Length: 53940, dtype: bool

# %%
diamonds[(diamonds.price >= 3000) & (diamonds.price <= 4000)]
# Out:
#       carat        cut color clarity  depth  table  price     x     y     z  \
# 1534   0.77      Ideal     E     SI1   62.5   56.0   3000  5.87  5.91  3.68
# 1535   0.93       Good     J     VS2   63.6   61.0   3000  6.16  6.08  3.89
# 1536   0.90    Premium     I     SI2   60.6   60.0   3001  6.23  6.28  3.79
# 1537   0.90  Very Good     I     SI2   62.5   58.0   3001  6.10  6.15  3.83
# 1538   0.90      Ideal     I     SI2   62.0   56.0   3001  6.16  6.20  3.83
# ...     ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 6206   1.00    Premium     G     SI2   62.2   57.0   3998  6.29  6.25  3.90
# 6207   1.01       Good     H     SI2   63.7   55.0   3999  6.32  6.37  4.04
# 6208   1.01    Premium     H     SI2   59.4   59.0   3999  6.53  6.56  3.89
# 6209   1.01      Ideal     I     SI1   60.6   57.0   3999  6.51  6.56  3.96
# 6210   0.70      Ideal     E     VS1   61.2   56.0   4000  5.72  5.75  3.51
#
#       price_gbp
# 1534    2220.00
# 1535    2220.00
# ...

# %%
price_cond = diamonds.price.between(3000, 4000)
is_ideal_cut = diamonds.cut == 'Ideal'
my_diamonds = diamonds[price_cond & is_ideal_cut]

# %%
my_diamonds
# Out:
#       carat    cut color clarity  depth  table  price     x     y     z  \
# 1534   0.77  Ideal     E     SI1   62.5   56.0   3000  5.87  5.91  3.68
# 1538   0.90  Ideal     I     SI2   62.0   56.0   3001  6.16  6.20  3.83
# 1543   0.60  Ideal     G    VVS1   62.1   56.0   3001  5.42  5.43  3.37
# 1550   0.72  Ideal     G    VVS2   61.6   55.0   3002  5.78  5.77  3.56
# 1553   0.76  Ideal     E     SI1   61.5   56.0   3003  5.89  5.91  3.63
# ...     ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 6190   1.01  Ideal     J     SI2   61.4   56.0   3997  6.44  6.47  3.97
# 6191   0.92  Ideal     D     SI2   60.3   56.0   3997  6.32  6.35  3.82
# 6197   1.03  Ideal     I     SI2   62.2   57.0   3997  6.50  6.46  4.03
# 6209   1.01  Ideal     I     SI1   60.6   57.0   3999  6.51  6.56  3.96
# 6210   0.70  Ideal     E     VS1   61.2   56.0   4000  5.72  5.75  3.51
#
#       price_gbp
# 1534    2220.00
# 1538    2220.74
# 1543    2220.74
# 1550    2221.48
# ...

# %%
my_diamonds.sort_values('carat', ascending=False, inplace=True)
# Out:
# /Users/shivajirao/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
my_diamonds
# Out:
#       carat    cut color clarity  depth  table  price     x     y     z  \
# 3247   1.28  Ideal     H      I1   61.9   56.0   3355  6.95  6.91  4.29
# 3137   1.27  Ideal     I      I1   62.3   56.0   3328  6.91  6.86  4.29
# 2877   1.25  Ideal     E      I1   60.9   56.0   3276  6.95  6.91  4.22
# 3080   1.24  Ideal     J     SI1   62.3   57.0   3312  6.86  6.81  4.26
# 3075   1.24  Ideal     I     SI2   62.5   57.0   3312  6.89  6.84  4.29
# ...     ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 2613   0.51  Ideal     D    VVS2   61.3   56.0   3223  5.14  5.15  3.16
# 2627   0.51  Ideal     E    VVS1   61.3   56.0   3226  5.21  5.13  3.17
# 3682   0.51  Ideal     D      IF   62.1   55.0   3446  5.12  5.13  3.19
# 3680   0.51  Ideal     D      IF   62.0   56.0   3446  5.14  5.18  3.20
# 2495   0.51  Ideal     E    VVS1   61.3   56.0   3197  5.13  5.21  3.17
#
#       price_gbp
# 3247    2482.70
# 3137    2462.72
# 2877    2424.24
# 3080    2450.88
# ...

# %%
my_diamonds.head(5)
# Out:
#       carat    cut color clarity  depth  table  price     x     y     z  \
# 3247   1.28  Ideal     H      I1   61.9   56.0   3355  6.95  6.91  4.29
# 3137   1.27  Ideal     I      I1   62.3   56.0   3328  6.91  6.86  4.29
# 2877   1.25  Ideal     E      I1   60.9   56.0   3276  6.95  6.91  4.22
# 3080   1.24  Ideal     J     SI1   62.3   57.0   3312  6.86  6.81  4.26
# 3075   1.24  Ideal     I     SI2   62.5   57.0   3312  6.89  6.84  4.29
#
#       price_gbp
# 3247    2482.70
# 3137    2462.72
# 2877    2424.24
# 3080    2450.88
# 3075    2450.88

# %%
my_diamonds[my_diamonds.carat == my_diamonds.carat.max()]
# Out:
#       carat    cut color clarity  depth  table  price     x     y     z  \
# 3247   1.28  Ideal     H      I1   61.9   56.0   3355  6.95  6.91  4.29
#
#       price_gbp
# 3247     2482.7

# %%
top5_report = my_diamonds[['cut', 'color', 'carat', 'price']].head()

# %%
my_diamonds.drop(columns=['x', 'y','z'])
# Out:
#       carat    cut color clarity  depth  table  price  price_gbp
# 3247   1.28  Ideal     H      I1   61.9   56.0   3355    2482.70
# 3137   1.27  Ideal     I      I1   62.3   56.0   3328    2462.72
# 2877   1.25  Ideal     E      I1   60.9   56.0   3276    2424.24
# 3080   1.24  Ideal     J     SI1   62.3   57.0   3312    2450.88
# 3075   1.24  Ideal     I     SI2   62.5   57.0   3312    2450.88
# ...     ...    ...   ...     ...    ...    ...    ...        ...
# 2613   0.51  Ideal     D    VVS2   61.3   56.0   3223    2385.02
# 2627   0.51  Ideal     E    VVS1   61.3   56.0   3226    2387.24
# 3682   0.51  Ideal     D      IF   62.1   55.0   3446    2550.04
# 3680   0.51  Ideal     D      IF   62.0   56.0   3446    2550.04
# 2495   0.51  Ideal     E    VVS1   61.3   56.0   3197    2365.78
#
# [1423 rows x 8 columns]

# %%
top5_report.to_csv('diamond-report.csv', index=False)

# %%
# !ls
# Out:
# Data Science.ipynb    diamond-report.csv    python-tutorial.ipynb

# %%
pd.read_csv('diamond-report.csv')
# Out:
#      cut color  carat  price
# 0  Ideal     H   1.28   3355
# 1  Ideal     I   1.27   3328
# 2  Ideal     E   1.25   3276
# 3  Ideal     J   1.24   3312
# 4  Ideal     I   1.24   3312

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_gbp
# 0     241.24
# 1     241.24
# 2     241.98
# 3     247.16
# 4     247.90

# %%
# np.where(condition, if_true, if_false)
diamonds['size'] = np.where(diamonds['carat'] < 1, 'small', 'big')
diamonds.groupby(['cut', 'size'])['price'].mean()
# Out:
# cut        size
# Fair       big      6558.534884
#            small    2092.404792
# Good       big      7273.546548
#            small    1792.915164
# Ideal      big      8563.427768
#            small    1546.212997
# Premium    big      8250.570344
#            small    1597.660132
# Very Good  big      8097.601639
#            small    1732.061444
# Name: price, dtype: float64

# %%
# %time
diamonds.groupby('cut').mean()
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.01 µs
#               carat      depth      table        price         x         y  \
# cut
# Fair       1.046137  64.041677  59.053789  4358.757764  6.246894  6.182652
# Good       0.849185  62.365879  58.694639  3928.864452  5.838785  5.850744
# Ideal      0.702837  61.709401  55.951668  3457.541970  5.507451  5.520080
# Premium    0.891955  61.264673  58.746095  4584.257704  5.973887  5.944879
# Very Good  0.806381  61.818275  57.956150  3981.759891  5.740696  5.770026
#
#                   z    price_gbp
# cut
# Fair       3.982770  3225.480745
# Good       3.639507  2907.359694
# Ideal      3.401448  2558.581058
# Premium    3.647124  3392.350701
# Very Good  3.559801  2946.502319

# %%
# %time
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 4.77 µs

# %%
# %time
diamonds.sort_values('price').head()
# Out:
# CPU times: user 3 µs, sys: 2 µs, total: 5 µs
# Wall time: 8.11 µs
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_gbp   size
# 0     241.24  small
# 1     241.24  small
# 2     241.98  small
# 3     247.16  small
# 4     247.90  small

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_gbp   size
# 0     241.24  small
# 1     241.24  small
# 2     241.98  small
# 3     247.16  small
# 4     247.90  small

# %%
diamonds.plot(kind='scatter', x='carat', y='price', c='green', cmap = 'coolwarm', s=1, figsize=(10,6))
plt.title("This Graph is Amazing", loc='left', size =20)
plt.ylabel('Price(USD)')
plt.savefig('cool-graph.png', dpi=192)

# %%
fig, axs = plt.subplots(2,2, figsize=(12,6))
axs[0][0].scatter(diamonds.carat, diamonds.price, color='green')
